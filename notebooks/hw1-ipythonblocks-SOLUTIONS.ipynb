# %%
from ipythonblocks import BlockGrid

# %%
grid = BlockGrid(10, 10, fill=(123, 234, 123))
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks570c1e85-0a58-44e0-a5a1-24618d30651e td {border: 1px solid white;}</style><table id="blocks570c1e85-0a58-44e0-a5a1-24618d30651e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %%
WHITE = (255, 255, 255)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLUE = (0, 0, 255)

# %% [markdown]
# ## Problem 1
#
# Modify the next cell to contain two for loops.  The first for loop should set the last row to red.  The second for loop should set the last column to white.

# %%
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(10):
    grid[9, i] = RED
for i in range(10):
    grid[i, 9] = WHITE

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksddc9762e-bc56-47f9-b59f-72d3f2fce4f0 td {border: 1px solid white;}</style><table id="blocksddc9762e-bc56-47f9-b59f-72d3f2fce4f0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %%
# Note -- you could do this in a single loop pretty easily:
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(10):
    grid[9, i] = RED
    grid[i, 9] = WHITE

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks467687fe-3c32-460a-a7af-3b18764f85f3 td {border: 1px solid white;}</style><table id="blocks467687fe-3c32-460a-a7af-3b18764f85f3" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %% [markdown]
# ## Problem 2
#
# Write a for loop so that every other cell along the diagonal is white. Your final grid should look like the following, BUT with using a for loop instead.
#
# Hint: you want to color on an even set of numbers.  You can either multiple i by 2 (i`*`2) or write an 'if' statement to test if i % 2 == 0.

# %%
grid = BlockGrid(10, 10, fill=(123, 234, 123))
grid[0, 0] = WHITE
grid[2, 2] = WHITE
grid[4, 4] = WHITE
grid[6, 6] = WHITE
grid[8, 8] = WHITE
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks534cbfde-3b60-4416-8ff1-f04c2df55b49 td {border: 1px solid white;}</style><table id="blocks534cbfde-3b60-4416-8ff1-f04c2df55b49" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %%
# one way to do this is to use an if statement:
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(10):
    if i % 2 == 0: # if even
        grid[i, i] = WHITE

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks46e87636-3a99-499e-83aa-cc6b611095db td {border: 1px solid white;}</style><table id="blocks46e87636-3a99-499e-83aa-cc6b611095db" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %%
# you can also do this by multiplying by 2:
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(5):  # <-- only go up to 5
    j = i*2
    grid[j, j] = WHITE

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7241f2ca-019b-42d3-ada7-20fac45079ad td {border: 1px solid white;}</style><table id="blocks7241f2ca-019b-42d3-ada7-20fac45079ad" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %%
# or, if you go read up on the range function, you can have the range function do the counting for you!
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(0, 10, 2):  # <-- step by 2
    grid[i, i] = WHITE

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3f0a0505-53b7-4784-93a0-86384c5a929f td {border: 1px solid white;}</style><table id="blocks3f0a0505-53b7-4784-93a0-86384c5a929f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 2]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 3]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 4]&#10;Color: (123, 234, 123)" style="width: 20px; height: 20px;background-color: rgb(123, 234, 123);"></td><td title="Index: [0, 5]&#10;Color: (123, 234, 123)" style="width: 2
# ...

# %% [markdown]
# ## Problem 3
#
# Write a nested for loop so that you color each row progressively more red, starting at black.  (See definition of RED above.)  Your final grid should look like the below, but with rows getting redder instead of columns.

# %%
grid = BlockGrid(10, 10, fill=(123, 234, 123))
grid[:,0] = (0, 0, 0)
grid[:,1] = (10, 0, 0)
grid[:,2] = (20, 0, 0)
grid[:,3] = (30, 0, 0)
grid[:,4] = (40, 0, 0)
grid[:,5] = (50, 0, 0)
grid[:,6] = (60, 0, 0)
grid[:,7] = (70, 0, 0)
grid[:,8] = (80, 0, 0)
grid[:,9] = (90, 0, 0)
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksaea7b46d-d0e7-48a7-9ea7-1cdcd15402d3 td {border: 1px solid white;}</style><table id="blocksaea7b46d-d0e7-48a7-9ea7-1cdcd15402d3" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (10, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(10, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (20, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(20, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (30, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(30, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (40, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(40, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (50, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(50, 0, 0);"></td>
# ...

# %%
# probably the simplest way to do it is like so:
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(10):
    grid[i, :] = (i*10, 0, 0)
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks96936531-f2b4-4c26-b4de-fdc2db1fda8f td {border: 1px solid white;}</style><table id="blocks96936531-f2b4-4c26-b4de-fdc2db1fda8f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %%
# but, there are many, many ways to skin a cat:
grid = BlockGrid(10, 10, fill=(123, 234, 123))

for i in range(0, 100, 10):
    grid[i / 10, :] = (i, 0, 0)
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks949d73c8-5060-4f3d-8563-1bd64e3eb02a td {border: 1px solid white;}</style><table id="blocks949d73c8-5060-4f3d-8563-1bd64e3eb02a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...
